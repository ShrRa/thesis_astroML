# %%
import pandas as pd
import AdsAbsRequester
from collections import Counter
import matplotlib.pyplot as plt

# %%
token="KDaPKeB4q7noKbg00u3gjlqszxYEWQ94YguJ0OmR"
requester=AdsAbsRequester.Requester(token,'testRequest')

# %%
searchCriteria=('database:astronomy','property:refereed', 
                'abs:("machine learning" or "neural network" or "perceptron" or "neural-network" or "random forest" or "support vector machine" or "self-organizing map" or "k-nearest neighbor")')

# %%
counts=pd.DataFrame(columns=['year','count'])

# %%
for year in range(1990,2021):
    q=searchCriteria+('year:'+str(year),)
    requester.setParams(q)
    requester.loadData()
    c=requester.response.json()['response']['numFound']
    counts=counts.append({'year':year,'count':c},ignore_index=True)
    print(year)
# Out:
# 2020

# %%
fig, ax=plt.subplots(1,1,figsize=(8,5),sharey='row')
plt.rcParams.update({'font.size': 14})
ax.plot(counts['year'],counts['count'],marker='x')
ax.set_xlabel('Year')
ax.set_ylabel('Number of publications')

plt.tight_layout()

# %%
counts
# Out:
#     year count
# 0   1990     4
# 1   1991     5
# 2   1992    13
# 3   1993    13
# 4   1994    32
# 5   1995    31
# 6   1996    39
# 7   1997    32
# 8   1998    36
# 9   1999    36
# 10  2000    32
# 11  2001    29
# 12  2002    28
# 13  2003    41
# 14  2004    55
# 15  2005    47
# 16  2006    50
# 17  2007    45
# 18  2008    67
# 19  2009    76
# 20  2010    59
# 21  2011    56
# 22  2012    94
# 23  2013    74
# 24  2014    99
# 25  2015   124
# 26  2016   155
# 27  2017   180
# 28  2018   276
# 29  2019   497
# 30  2020   597
